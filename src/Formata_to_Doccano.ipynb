# %% [markdown]
# ## Imports

# %%
from datasets import Dataset
import json

# %% [markdown]
# ## Constantes

# %%
dir = "../"
dir_dataset = "data/rotulacao/datasets/"
arquivo_alvo = "rotulando_dataset_concatenate.json"

dir_doccano = "data/rotulacao/doccano_data/"
arquivo_resultado = f"{arquivo_alvo}"

# %% [markdown]
# ## Lendo Dataset

# %%
dataset = Dataset.from_json(f"{dir}{dir_dataset}{arquivo_alvo}")
# Out:
# Using custom data configuration default-195592d7a2509507
# Downloading and preparing dataset json/default to /home/thiago/.cache/huggingface/datasets/json/default-195592d7a2509507/0.0.0...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /home/thiago/.cache/huggingface/datasets/json/default-195592d7a2509507/0.0.0. Subsequent calls will reuse this data.

# %%
dataset
# Out:
# Dataset({
#     features: ['created_time', 'message', 'permalink_url', 'id_post', 'dataset_origem', 'index'],
#     num_rows: 200
# })

# %% [markdown]
# ## Criando Arquivo para Doccano

# %%
dict_dados = list([])
for dado in dataset:
    dict_dados.append({"text": dado["message"], "label": [None], "index": dado["index"]})

# %%
dict_dados
# Out:
# [{'text': 'Excelente! Porém ainda estou à espera da minha do mês de Agosto. Está demorando, CN!...',
#   'label': [None],
#   'index': 21915},
#  {'text': 'Um luxo', 'label': [None], 'index': 29421},
#  {'text': 'Por +empresas assim para um mundo melhor!',
#   'label': [None],
#   'index': 2551},
#  {'text': 'Prosa maneira ouro, envelhecida 2 anos em barris de amburana.',
#   'label': [None],
#   'index': 20673},
#  {'text': 'Paula Reami ', 'label': [None], 'index': 13974},
#  {'text': 'Maríbondo', 'label': [None], 'index': 18598},
#  {'text': 'Cara que dói!', 'label': [None], 'index': 32084},
#  {'text': 'Kero pro próximo esquenta Giovanna Caneloi Paloma Reis Muniki Del Rio',
#   'label': [None],
#   'index': 10647},
#  {'text': 'Obrigada amiga!', 'label': [None], 'index': 5241},
#  {'text': 'Onde encontro pra comprar em Belo Horizonte MG.?',
#   'label': [None],
#   'index': 26872},
#  {'text': 'E profissional. 🤗🤗🤗', 'label': [None], 'index': 2744},
#  {'text': 'Queria um de malte vc tem', 'label': [None], 'index': 24507},
#  {'text': 'Essa cachaça é top maravilhosa vale a pena degusta-lá ',
#   'label': [None],
#   'index': 26873},
#  {'text': 'Voces dois fazem uma dupla espetacular',
#   'label': [None],
#   'index': 8279},
#  {'text': 'Diogo James Braghin .Paulo Paulo Ricardo Braghin',
#   'label': [None],
#   'index': 30085},
#  {'text': 'Germana, Guaraciaba e ...', 'label': [None], 'index': 20810},
#  {'text': '👊👊👊👊', 'label': [None], 'index': 27264},
#  {'text': 'THE  BEST !!', 'label': [None], 'index': 34483},
#  {'text': '😉', 'label': [None], 'index': 24220},
#  {'text': 'Eu recomendo 😍', 'label': [None], 'index': 21463},
#  {'text': 'Graciele Melo de Barros', 'label': [None], 'index': 16308},
#  {'text': 'Jessica Machado Ferreira vamos fazer kkkkkkk 🤗🙈',
#   'label': [None],
#   'index': 13542},
#  {'text': 'Thyago Speziali, Clayton Gandra, Flávio Scholbi, Marcos Vinicius Paolinelli Pessoal,  enviem para os outros amigos.',
#   'label': [None],
#   'index': 24838},
#  {'text': 'Feliz natal, um prospero ano novo de paz, saúde e prosperidade 🎅',
#   'label': [None],
#   'index': 11943},
#  {'text': 'Izabela Hudson Miranda lembrei de vc',
#   'label': [None],
#   'index': 12829},
#  {'text': 'virada do ano já?', 'label': [None], 'index': 538},
#  {'text': 'Pena que não é pra minha casa...to poupando pra comprar uma...',
#   'label': [None],
#   'index': 25014},
#  {'text': 'O governo que mais destruiu nossa Amazonia e vcs da @sanhacu presenteando como se eles fossem defensores da natureza. Sanhaçu nunca mais.',
#   'label': [None],
#   'index': 1809},
#  {'text': 'Thiago Gama Nascimento', 'label': [None], 'index': 18666},
#  {'text': 'Bebo nao', 'label': [None], 'index': 10429},
#  {'text': '👍😋', 'label': [None], 'index': 31380},
#  {'text': 'Kkkkkkkkkkk', 'label': [None], 'index': 24275},
#  {'text': 'Boa tarde Deus', 'label': [None], 'index': 7196},
#  {'text': 'Uma das melhores do Brasil!!!', 'label': [None], 'index': 3924},
#  {'text': 'Qualidade top 10. Excelente cachaça!♥',
#   'label': [None],
#   'index': 3282},
#  {'text': 'Quê grades camtoresdesusesovoseis São demuitoquerido',
#   'label': [None],
#   'index': 8143},
#  {'text': 'Saúde', 'label': [None], 'index': 32213},
#  {'text': '👏👏👏👏👏👏👏👏', 'label': [None], 'index': 8432},
#  {'text': 'Essa é show', 'label': [None], 'index': 26584},
#  {'text': 'A melhor de Minas se chama Costa rica ou Dombre fabricação Guarani Minas gerais',
#   'label': [None],
#   'index': 16693},
#  {'text': 'Masaropi', 'label': [None], 'index': 21100},
#  {'text': 'Rodolfo Barbosa Adriano Hipolito Monica Meneses Patricia Silva Lygia França Marco Fontes Jessica Santos.......ESTOU ACEITANDO ESSE MARAVILHOSO PRESENTE.',
#   'label': [None],
#   'index': 11219},
#  {'text': 'Bater no liquidificador por sete minutos? Caramba, muito tempo pra uma medida rala e pouca.',
#   'label': [None],
#   'index': 15254},
#  {'text': 'Ezequiel Ribeiro Ribeiro', 'label': [None], 'index': 17070},
#  {'text': 'Geraldo Marcos Souza Garcia\nMário Geraldo Margotto',
#   'label': [None],
#   'index': 30528},
#  {'text': 'Celia Daniel, Stefani Cândido Quero',
#   'label': [None],
#   'index': 30597},
#  {'text': 'Regiane Diomario.  Luisiane. Borges',
#   'label': [None],
#   'index': 29972},
#  {'text': 'bento albino prata', 'label': [None], 'index': 14321},
#  {'text': 'Domingo dia dos pais Chico Mineiro 👍👍👍👍',
#   'label': [None],
#   'index': 15178},
#  {'text': 'Reginaldo B Paula Bruno Otávio Serra Douglas Gonzaga Gonzaga Hilbert Do Valle Silvio Alberto Alexandre Lima só pé de cana',
#   'label': [None],
#   'index': 23707},
#  {'text': 'i tão vomus tom cacsa. kkkkkkkk', 'label': [None], 'index': 29230},
#  {'text': 'Parabéns,Sucesso! 🥂🎂', 'label': [None], 'index': 33461},
#  {'text': 'O melhor é o limpo: imbatível. \n;-)',
#   'label': [None],
#   'index': 19468},
#  {'text': 'Sou fã de todos vcs', 'label': [None], 'index': 6766},
#  {'text': 'Felicidades e saúde sempre , Tio Moacir',
#   'label': [None],
#   'index': 1712},
#  {'text': 'Parabéns  meu querido  João João Luiz de Faria que venham muitos mais prêmios  e sucesso!!! 👏👏👏👏👏👏',
#   'label': [None],
#   'index': 32911},
#  {'text': 'Katia Rocha 😂 sera??', 'label': [None], 'index': 4324},
#  {'text': 'Parabens!!!!!', 'label': [None], 'index': 7714},
#  {'text': 'Nega Fulô e Caranguejo.', 'label': [None], 'index': 17932},
#  {'text': 'Também acho amo vocês. Mais faltou Eduardo Costa. Vocês são todos unidos pela música mais falta o Dudu ai.😘😘',
#   'label': [None],
#   'index': 5912},
#  {'text': 'Cachaça paaaar favaaaar!', 'label': [None], 'index': 34026},
#  {'text': 'Daniela Borba', 'label': [None], 'index': 9008},
#  {'text': 'Aí sim vai mostrar pra turma em araras hem',
#   'label': [None],
#   'index': 8347},
#  {'text': 'Taca cachaça pra nós!!! Faz chover pinga do céu!! 🎶🎶🎶Aêêê VELHO BARREIRO, parabéns!!!! \nhttps://m.youtube.com/user/musicavelhobarreiro',
#   'label': [None],
#   'index': 4854},
#  {'text': 'Jean Pacheco e bota  cachaça  nisso 😆😆😆',
#   'label': [None],
#   'index': 18416},
#  {'text': 'Lidiane Meneses X Vandin olha isso 👍🏽',
#   'label': [None],
#   'index': 13608},
#  {'text': 'Lucas Rosado', 'label': [None], 'index': 10226},
#  {'text': 'Andre Santos Celso Viriato', 'label': [None], 'index': 30364},
#  {'text': 'Marina Cristina', 'label': [None], 'index': 7869},
#  {'text': 'Qual o valor?', 'label': [None], 'index': 29203},
#  {'text': 'Luan Passos', 'label': [None], 'index': 32633},
#  {'text': 'Uhu! Cunhado Pedro Bettencourt Dos Santos, To sonhando com uma caipirinha Magnífica feita por vc! Kkkkk',
#   'label': [None],
#   'index': 32953},
#  {'text': 'Maldinha, essa deve ser boa.kkkk', 'label': [None], 'index': 27704},
#  {'text': 'Que lindo!', 'label': [None], 'index': 3278},
#  {'text': '👏👏👏', 'label': [None], 'index': 26990},
#  {'text': '51, Corote e a Raspa Goela!', 'label': [None], 'index': 14336},
#  {'text': 'Vou tomar também 🤗🤗', 'label': [None], 'index': 31032},
#  {'text': 'Maurici', 'label': [None], 'index': 1365},
#  {'text': 'ela é nota  M i l', 'label': [None], 'index': 25795},
#  {'text': 'É verdade Angela Maria? 😂😂😂😂', 'label': [None], 'index': 15939},
#  {'text': 'Que legal!!! Amei...', 'label': [None], 'index': 2595},
#  {'text': 'Parabéns!!!!', 'label': [None], 'index': 33498},
#  {'text': 'Eu', 'label': [None], 'index': 22241},
#  {'text': 'Ai sim deu água na boca 👄 pena q tenho dimdim',
#   'label': [None],
#   'index': 15110},
#  {'text': 'Cocorrendo', 'label': [None], 'index': 25479},
#  {'text': 'Olha isso Amor Rosana Ghiraldi👆diaaaaa🌹💋❤️🙏',
#   'label': [None],
#   'index': 28030},
#  {'text': 'Quero compra a cachasa de vcs como faso',
#   'label': [None],
#   'index': 19701},
#  {'text': 'É de qual localidade', 'label': [None], 'index': 15567},
#  {'text': 'Cachaça de Boa qualidade tem seu lugar .',
#   'label': [None],
#   'index': 11871},
#  {'text': 'Danilo Cesar', 'label': [None], 'index': 15473},
#  {'text': 'Top', 'label': [None], 'index': 16553},
#  {'text': 'Fenomenal!!!', 'label': [None], 'index': 28268},
#  {'text': 'muito bom', 'label': [None], 'index': 407},
#  {'text': 'ANTEPASTO DE JILÓ, SÓ FALTA ADICIONAR CARQUEIJO',
#   'label': [None],
#   'index': 25421},
#  {'text': 'Agora bateu....eita....ondao', 'label': [None], 'index': 19520},
#  {'text': 'Kariely  putzzzzzzz', 'label': [None], 'index': 5771},
#  {'text': 'Meus amigos não bebem.', 'label': [None], 'index': 23692},
#  {'text': 'SUCESSO FAMÍLIA  SANHAÇU', 'label': [None], 'index': 2520},
#  {'text': 'Parabéns Carlinhos e Lelida. Tanta dedicação , pesquisa e excelência, só podem levar ao sucesso. De Bom Despacho para o mundo.',
#   'label': [None],
#   'index': 23289},
#  {'text': 'Eduardo Costa Leonardo', 'label': [None], 'index': 22932},
#  {'text': 'Umburana', 'label': [None], 'index': 22916},
#  {'text': 'Opa tô em bh', 'label': [None], 'index': 21485},
#  {'text': 'CARNAVAL', 'label': [None], 'index': 21137},
#  {'text': 'Qual o valor?', 'label': [None], 'index': 7426},
#  {'text': 'Sto Grau', 'label': [None], 'index': 20753},
#  {'text': 'Muito bom eu já  comi', 'label': [None], 'index': 12801},
#  {'text': 'Que delícia', 'label': [None], 'index': 29213},
#  {'text': 'É um universo de muitos rótulos fantástico, mais seria egoísmo eleger uma apenas ,dentre varias maravilhosas !!',
#   'label': [None],
#   'index': 20631},
#  {'text': 'Eu ainda não tomei essa cachaça aí mais quando eu estiver indo para Bahia nas minhas férias eu vou fazer questão de compra  uma garrafa dessa cachaça prazer de Minas bom deve ser gostosa né como toda pinga né kkkkkkkkk mais eu vou provar',
#   'label': [None],
#   'index': 16059},
#  {'text': 'pode descer do carro e entrar na loja ?',
#   'label': [None],
#   'index': 5313},
#  {'text': '👏', 'label': [None], 'index': 2374},
#  {'text': 'Maísa Tolentino ;)', 'label': [None], 'index': 19695},
#  {'text': '👏👏👏👏👏👏', 'label': [None], 'index': 7108},
#  {'text': 'Camila Fernanda', 'label': [None], 'index': 15361},
#  {'text': 'Corrigindo, Famosinha de Minas, Salinas e Claudionor',
#   'label': [None],
#   'index': 21441},
#  {'text': 'Elk Barreto usa colar Patrícia Moura Biojoias',
#   'label': [None],
#   'index': 3945},
#  {'text': 'Aline Dourado Só deixou saudades... :-(',
#   'label': [None],
#   'index': 4432},
#  {'text': 'Existem quatro coisa mundo que sustenta o homem em pé, a carne do boi curraleiro e o toucinho do porco baé a cachaça 51 e o amor de uma mulher!!!',
#   'label': [None],
#   'index': 16989},
#  {'text': '🤩🌹', 'label': [None], 'index': 2279},
#  {'text': 'Eita por fala nisso amanhã começa o 5° fest pinga aq de Rio Claro SP!!! Bebê deitado para não dar trabalho!!! Ow mundão veio',
#   'label': [None],
#   'index': 16654},
#  {'text': 'Mayara Thairiny', 'label': [None], 'index': 10182},
#  {'text': 'Eduardo Vieira Munhoz\nEduardo Usiminas',
#   'label': [None],
#   'index': 30456},
#  {'text': 'Minha caipirinha já está pronta, tchau !.',
#   'label': [None],
#   'index': 23644},
#  {'text': 'Têm sim', 'label': [None], 'index': 14228},
#  {'text': 'Cachaça de salinas puro néctar rsrsrsrsrs !!!!',
#   'label': [None],
#   'index': 1091},
#  {'text': 'Fantástico lindo.', 'label': [None], 'index': 3541},
#  {'text': 'Quero provar', 'label': [None], 'index': 28323},
#  {'text': 'Estou apreciando neste momento...😍',
#   'label': [None],
#   'index': 31198},
#  {'text': 'Logo estaremos juntos no SBT  responderemos seu email na próxima semana e embarcaremos ao sucesso absoluto \nUm abraço',
#   'label': [None],
#   'index': 34004},
#  {'text': 'Por gostar mto d vc queria vc comigo ^^ =D',
#   'label': [None],
#   'index': 559},
#  {'text': 'Eita meu Deus!  só   é Fera do Sertanejo  ,vai ser bom dimais, amo vcs meus LINDOS, PRINCIPALMENTE  VC  LEO❤❤',
#   'label': [None],
#   'index': 6971},
#  {'text': 'a minha vai ter caipirinha a vontade......DOM TAPARO.......',
#   'label': [None],
#   'index': 11436},
#  {'text': 'Mas que tall eu quero Gerson Steffen Fabricio Godoi',
#   'label': [None],
#   'index': 29990},
#  {'text': 'Vou fazer', 'label': [None], 'index': 15722},
#  {'text': 'Barril de umburana', 'label': [None], 'index': 22982},
#  {'text': 'Eu quero kkkk', 'label': [None], 'index': 22039},
#  {'text': 'Mariele Liberato', 'label': [None], 'index': 12280},
#  {'text': 'Parabéns  meu grande amigo e parceiro',
#   'label': [None],
#   'index': 33373},
#  {'text': 'Que chic !!!', 'label': [None], 'index': 24430},
#  {'text': 'Foto: Darlan Fuzuca', 'label': [None], 'index': 31274},
#  {'text': 'Aprecio muito essa cachaça de qualidade  , Sebatiana é top!',
#   'label': [None],
#   'index': 15568},
#  {'text': 'Pitú no bar Pedra Pequena, SP', 'label': [None], 'index': 15179},
#  {'text': 'Eu vou querer experimentar, com certeza vou comprar',
#   'label': [None],
#   'index': 11353},
#  {'text': 'Feliz Natal Elke, pra toda sua familia! Familia linda!!!! Amei conhecer vocês!!!!',
#   'label': [None],
#   'index': 2880},
#  {'text': 'Salete', 'label': [None], 'index': 13636},
#  {'text': 'Nossa ja perdi as conta quantas vezes Iso me aconteceu kkkkkkk.',
#   'label': [None],
#   'index': 24994},
#  {'text': 'Gostaria de ganhar, porque não conheço',
#   'label': [None],
#   'index': 29755},
#  {'text': 'Gostaria de comprar para presente!!!!!',
#   'label': [None],
#   'index': 28301},
#  {'text': 'kkkkkkkkkkkkk', 'label': [None], 'index': 22630},
#  {'text': 'Néia Corazza, anota ai pra ceia', 'label': [None], 'index': 15816},
#  {'text': 'Pra substituir a sueca Ráulison Vale',
#   'label': [None],
#   'index': 18334},
#  {'text': 'Essa é linda!', 'label': [None], 'index': 26543},
#  {'text': 'Essa história merecia um documentário!\nParabéns ao aniversariante!!🥂👏😘',
#   'label': [None],
#   'index': 1670},
#  {'text': 'Drorriane Carvalho', 'label': [None], 'index': 10857},
#  {'text': 'Romualdo Fontes', 'label': [None], 'index': 30798},
#  {'text': 'Deve ser muito boa ...', 'label': [None], 'index': 26758},
#  {'text': 'Já recebi e já tomei, muiiiito boa',
#   'label': [None],
#   'index': 11673},
#  {'text': 'Lauziane Ramos. Olha. Isso. Tá igual. Eu. !!  😂😂',
#   'label': [None],
#   'index': 7529},
#  {'text': 'Fernanda Simões veja isto', 'label': [None], 'index': 18356},
#  {'text': 'Só aqui em Maragogipe Terra Natal',
#   'label': [None],
#   'index': 16350},
#  {'text': 'Parabéns Antenor e Prosa Mineira por esse primor de cachaça. Merecida nota 10!',
#   'label': [None],
#   'index': 16363},
#  {'text': 'Israel Costa', 'label': [None], 'index': 1161},
#  {'text': 'Aquilo no palito é uma barata?', 'label': [None], 'index': 12194},
#  {'text': 'otima moradia', 'label': [None], 'index': 284},
#  {'text': 'Bbzinho Helton S. Furlan, a CASA DA BEBIDA vai fazer do nosso reveillon muito mais alegre em todos os sentidos com a Vodka Grey Goose, vamos poder comemorar até 2012 chegar em grande estilo!!! Obrigada Casa da Bebida!!!!',
#   'label': [None],
#   'index': 580},
#  {'text': 'até o dia 14', 'label': [None], 'index': 4046},
#  {'text': 'Oxé cachaça gostosa danada...', 'label': [None], 'index': 4160},
#  {'text': 'Wanderson Vicente tô esperando a minha até hoje...',
#   'label': [None],
#   'index': 32069},
#  {'text': 'Queria que tivesse uma no Rio Grande do Sul.☺️😍',
#   'label': [None],
#   'index': 5362},
#  {'text': 'Opa mais uma data a comemorar Dia Mundial da Filosofia!',
#   'label': [None],
#   'index': 5006},
#  {'text': 'são vários......saudade de muitos',
#   'label': [None],
#   'index': 18419},
#  {'text': 'Cachaça Usina Velha', 'label': [None], 'index': 20159},
#  {'text': 'Qual o preco dessa cachaças e como eu faço pra comprar',
#   'label': [None],
#   'index': 1047},
#  {'text': '💖💖💖💖💖💖👊👊👊👊👊👊', 'label': [None], 'index': 18054},
#  {'text': 'Pois é amigo André Bueno Andreta, essa nossa cachaça Sanhaçu - cachaça orgânica produzida pela família de Elk Sanhaçu podemos afirmar sem dúvidas que é a melhor cachaça de Pernambuco. Conheço o engenho, e mais ainda, a cachaça. Um abraço.',
#   'label': [None],
#   'index': 3073},
#  {'text': 'Melhor cachaça...👍👍👍', 'label': [None], 'index': 29411},
#  {'text': 'Juba Junior', 'label': [None], 'index': 20986},
#  {'text': 'Onde comprar..', 'label': [None], 'index': 12600},
#  {'text': 'Onde compro aqui em franca', 'label': [None], 'index': 922},
#  {'text': 'Esta e da melhor qualidade, adoro',
#   'label': [None],
#   'index': 16813},
#  {'text': 'Minha sidade natal ja trabalei comseu pai morava nas posi',
#   'label': [None],
#   'index': 14753},
#  {'text': 'Claudionor\nPiragibana\nSalineira',
#   'label': [None],
#   'index': 11880},
#  {'text': 'Que  delicia!', 'label': [None], 'index': 26302},
#  {'text': 'Boa tarde', 'label': [None], 'index': 31565},
#  {'text': 'eu  queria  tanto   ganhar  dair rodrigues  Dair Lemes',
#   'label': [None],
#   'index': 31952},
#  {'text': 'Alessandra Almeida ❤', 'label': [None], 'index': 8650},
#  {'text': 'Vai uma amor Jaqueline BM? 🍸🍸', 'label': [None], 'index': 29152},
#  {'text': 'Eu quero manda pra min  !!!', 'label': [None], 'index': 995},
#  {'text': 'Deve ser boa mesmo pelas referências!',
#   'label': [None],
#   'index': 27178},
#  {'text': 'Parabéns, João da Magnífica!!!Toda felicidade possível à você e família! ❤👏🏿',
#   'label': [None],
#   'index': 32159},
#  {'text': 'Regis De Lima Moises Barros de Lima',
#   'label': [None],
#   'index': 30548},
#  {'text': 'Gustavo Machado Perche Perche ', 'label': [None], 'index': 27258},
#  {'text': 'Olímpio De Miranda Júnior olha aí',
#   'label': [None],
#   'index': 20567},
#  {'text': '#Eduardo Costa  # Leonardo se não tive fica desproporcional do rei da cachaça',
#   'label': [None],
#   'index': 6301},
#  {'text': 'Cachaça do chefe.', 'label': [None], 'index': 12010},
#  {'text': 'Sagatiba!', 'label': [None], 'index': 21594},
#  {'text': 'Jailson Avelino esse que tu tem que comer amor. Kkkkkkkkk',
#   'label': [None],
#   'index': 13361},
#  {'text': 'Dificilmente eu ter inveja,mais viver do jeito desses dois....eu cantaria pro resto da vida,rsrs, vamos q vamos.',
#   'label': [None],
#   'index': 9657},
#  {'text': 'Só falta o Gustavo Lima 👏🏻👏🏻👏🏻👏🏻', 'label': [None], 'index': 7165},
#  {'text': 'Bandas?', 'label': [None], 'index': 31615}]

# %%
with open(f"{dir}{dir_doccano}{arquivo_resultado}", "w") as arquivo:
    json.dump(dict_dados, arquivo, indent=4)
    arquivo.close()
