# %% [markdown]
# ## Imports

# %%
from datasets import Dataset

# %% [markdown]
# ## Constantes

# %%
dir = "../"
dir_dataset = "data/rotulacao/datasets/"
arquivo_alvo = "rotulando_dataset_concatenate.json"

dir_doccano = "data/rotulacao/doccano_data/"
arquivo_resultado = f"{arquivo_alvo}.txt"

# %% [markdown]
# ## Lendo Dataset

# %%
dataset = Dataset.from_json(f"{dir}{dir_dataset}{arquivo_alvo}")
# Out:
# Using custom data configuration default-381f644f487efd15
# Downloading and preparing dataset json/default to /home/thiago/.cache/huggingface/datasets/json/default-381f644f487efd15/0.0.0...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /home/thiago/.cache/huggingface/datasets/json/default-381f644f487efd15/0.0.0. Subsequent calls will reuse this data.

# %%
dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'created_time', 'message', 'permalink_url', 'id_post', 'dataset_origem'],
#     num_rows: 200
# })

# %% [markdown]
# ## Criando Arquivo para Doccano

# %%
dict_dados = list([])
for dado in dataset:
    dict_dados.append({"text": dado["message"], "label": [None], "index": dado["Unnamed: 0"], "id_post": dado["id_post"]})

# %%
dict_dados
# Out:
# [{'text': 'Isabella Lopes',
#   'label': [None],
#   'index': 2275,
#   'id_post': '403465119681680_3212609728767191'},
#  {'text': 'Ebaaaa, olha isso meus filhos!!!',
#   'label': [None],
#   'index': 2,
#   'id_post': '366862246737093_3286725784750710'},
#  {'text': 'Cachaça com limão.',
#   'label': [None],
#   'index': 5738,
#   'id_post': '419227044768933_1836360853055538'},
#  {'text': 'Boa noite',
#   'label': [None],
#   'index': 1644,
#   'id_post': '403465119681680_3482456958449132'},
#  {'text': 'Vai dá ruim kkk',
#   'label': [None],
#   'index': 2122,
#   'id_post': '678132495559046_3528569993848601'},
#  {'text': 'O Leonardo manda um litro pra mim',
#   'label': [None],
#   'index': 3277,
#   'id_post': '678132495559046_1831531736885777'},
#  {'text': 'Feliz natal! ',
#   'label': [None],
#   'index': 90,
#   'id_post': '264760870213527_3717005968322316'},
#  {'text': 'Pega fogo cabaré eror kkkkk',
#   'label': [None],
#   'index': 4398,
#   'id_post': '678132495559046_1411592662213022'},
#  {'text': 'Queria um desse!!!😆😵😢',
#   'label': [None],
#   'index': 4300,
#   'id_post': '678132495559046_1413602048678750'},
#  {'text': 'Aí Thiago Auad ... Kkkkkkk To com duas dessas 😂',
#   'label': [None],
#   'index': 12120,
#   'id_post': '419227044768933_1272110839480545'},
#  {'text': 'Ana Clara de Oliveira',
#   'label': [None],
#   'index': 21,
#   'id_post': '504821172912906_3474877049240622'},
#  {'text': 'pode crer.. vamos copiar vamo.... kkkkk',
#   'label': [None],
#   'index': 246,
#   'id_post': '120086268098178_336074246499378'},
#  {'text': 'Aprecie com moderação!',
#   'label': [None],
#   'index': 127,
#   'id_post': '100997261363161_187485026047717'},
#  {'text': 'Opa Rud J. Neto chamou a pessoa certa!kkkkkk (2)',
#   'label': [None],
#   'index': 386,
#   'id_post': '120086268098178_183138965126241'},
#  {'text': 'Vai ser massa!!! =D',
#   'label': [None],
#   'index': 668,
#   'id_post': '120086268098178_186924451394439'},
#  {'text': 'Marcus Vinicius',
#   'label': [None],
#   'index': 510,
#   'id_post': '504821172912906_1342251635836518'},
#  {'text': 'Keila Aparecida Barbosa Vieira',
#   'label': [None],
#   'index': 1852,
#   'id_post': '403465119681680_3364859013542261'},
#  {'text': 'Parabéns Juliano, muito sucesso! 👏👏👏',
#   'label': [None],
#   'index': 9854,
#   'id_post': '419227044768933_1690421547649470'},
#  {'text': 'Já quero uma dessa para minha coleção ❤ Maria Fernanda Serrano Piastrelli precisamos ir no alambique garantir a Nossa!! !',
#   'label': [None],
#   'index': 456,
#   'id_post': '154327584714197_797472203733062'},
#  {'text': 'ParA de beber, !!!e vai para uma academia...cuidado com o coração....o sucesso passa.....vai cuidar da saúde....',
#   'label': [None],
#   'index': 5103,
#   'id_post': '678132495559046_1392962117409410'},
#  {'text': 'Onde fica a loja . Gostaria de conhecer',
#   'label': [None],
#   'index': 2177,
#   'id_post': '403465119681680_3326132427414920'},
#  {'text': 'Já apreciei umas hj.',
#   'label': [None],
#   'index': 2732,
#   'id_post': '403465119681680_2929732503721583'},
#  {'text': 'Edson Cruz',
#   'label': [None],
#   'index': 11454,
#   'id_post': '419227044768933_1475881462436814'},
#  {'text': 'Pó  meu essa deve ser da boa loko pra dar uma golada dessa cachaça.',
#   'label': [None],
#   'index': 507,
#   'id_post': '929114380449752_1627482690612914'},
#  {'text': 'Leila Mara Palmieri Ramim acho chique você ter um😌',
#   'label': [None],
#   'index': 3846,
#   'id_post': '678132495559046_1459415090764112'},
#  {'text': 'Faltou o Gustavo Lima! 😃',
#   'label': [None],
#   'index': 910,
#   'id_post': '678132495559046_3528569993848601'},
#  {'text': '😲😲😲😲😲😲😲',
#   'label': [None],
#   'index': 2755,
#   'id_post': '403465119681680_2929435240417976'},
#  {'text': 'Sem Eduardo Costa e Gustavo Lima ?',
#   'label': [None],
#   'index': 1371,
#   'id_post': '678132495559046_3528569993848601'},
#  {'text': 'Anne Caroline',
#   'label': [None],
#   'index': 2421,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'Estamos 100% com vocês.',
#   'label': [None],
#   'index': 2348,
#   'id_post': '678132495559046_3119318688107069'},
#  {'text': 'Fabi Salles',
#   'label': [None],
#   'index': 1231,
#   'id_post': '419227044768933_3287903577901251'},
#  {'text': 'vão te causar surpresas....',
#   'label': [None],
#   'index': 4540,
#   'id_post': '419227044768933_2183616711663282'},
#  {'text': 'Melhor não há.',
#   'label': [None],
#   'index': 456,
#   'id_post': '929114380449752_1643569942337522'},
#  {'text': 'Eduardo Costa tá muito bagaceiro e muda muito ritimo da música. Já eras.',
#   'label': [None],
#   'index': 718,
#   'id_post': '678132495559046_3528569993848601'},
#  {'text': 'Vou faser',
#   'label': [None],
#   'index': 1412,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'Conhece nego Negrão Carioca rsrsrs',
#   'label': [None],
#   'index': 885,
#   'id_post': '445596452143103_1029317033771039'},
#  {'text': 'Atitude nobre dessa empresa Parabéns bora gente pro saity comprar produtos dom tapparo',
#   'label': [None],
#   'index': 2418,
#   'id_post': '678132495559046_2721393391232936'},
#  {'text': 'Olha aí marcos rosa',
#   'label': [None],
#   'index': 3261,
#   'id_post': '403465119681680_2583187228376114'},
#  {'text': 'Eu quero Amanda cetim  Leandra v \nFracieli v',
#   'label': [None],
#   'index': 5025,
#   'id_post': '403465119681680_1964824473545729'},
#  {'text': 'Legal essa loja. Passa cartão e os preços são bons',
#   'label': [None],
#   'index': 89,
#   'id_post': '120086268098178_874934905946640'},
#  {'text': 'Boa...',
#   'label': [None],
#   'index': 13245,
#   'id_post': '419227044768933_981333135224985'},
#  {'text': 'Tenho dificuldades para encontrar esta rua só com waze. Gostaria que o espaço ficasse pequeno para Tanta gente Acho que tem pouco funcionário .Avante ,olha o serviço ...',
#   'label': [None],
#   'index': 746,
#   'id_post': '289946744351052_2552411028104601'},
#  {'text': 'http://www.cachacarianacional.com.br/busca?busca=cacha%C3%A7a+salinas',
#   'label': [None],
#   'index': 12514,
#   'id_post': '419227044768933_1175869505771346'},
#  {'text': 'Parabéns e bastante sucesso!',
#   'label': [None],
#   'index': 1748,
#   'id_post': '289946744351052_1335219556490427'},
#  {'text': 'FALTOU EU AI.',
#   'label': [None],
#   'index': 14090,
#   'id_post': '419227044768933_637752389583063'},
#  {'text': 'Eduardo Rosina\nItamar Tobias',
#   'label': [None],
#   'index': 4704,
#   'id_post': '403465119681680_1964824473545729'},
#  {'text': 'Caraca... Excelências',
#   'label': [None],
#   'index': 2842,
#   'id_post': '403465119681680_2886956934665807'},
#  {'text': 'A minha tbm',
#   'label': [None],
#   'index': 6278,
#   'id_post': '678132495559046_1107992795906345'},
#  {'text': 'NÃO PODEREI MAS APRECIAR MEU CORAÇAO ME TRAIU',
#   'label': [None],
#   'index': 4807,
#   'id_post': '419227044768933_2034697316555223'},
#  {'text': '👏👏👏👏👏',
#   'label': [None],
#   'index': 116,
#   'id_post': '264760870213527_3055652107791042'},
#  {'text': 'Olhem isso André Lemes e Natalia Bittencourt 😌',
#   'label': [None],
#   'index': 4410,
#   'id_post': '419227044768933_2341178122573806'},
#  {'text': 'Lindo o lugar tiver o prazer de conhce muito',
#   'label': [None],
#   'index': 570,
#   'id_post': '289946744351052_2808558445823190'},
#  {'text': 'Rithelli Monteiro\nFranciana Gomes',
#   'label': [None],
#   'index': 4785,
#   'id_post': '403465119681680_1964824473545729'},
#  {'text': 'Decisão!!!\nPrata...\nÓtima!',
#   'label': [None],
#   'index': 3801,
#   'id_post': '419227044768933_2604935762864706'},
#  {'text': 'Carvalho...',
#   'label': [None],
#   'index': 735,
#   'id_post': '419227044768933_3675957795762492'},
#  {'text': 'E para quem não fica bêbado qual é o tempo?KKKKKKKKKKKKKKKKKKKK',
#   'label': [None],
#   'index': 252,
#   'id_post': '120086268098178_327544497352353'},
#  {'text': 'Poderia passar a receita',
#   'label': [None],
#   'index': 3912,
#   'id_post': '419227044768933_2592837884074494'},
#  {'text': '👏👏👏👏',
#   'label': [None],
#   'index': 3420,
#   'id_post': '419227044768933_2809419502416330'},
#  {'text': 'Luiz Henrique Mariano',
#   'label': [None],
#   'index': 1791,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'onde acha para comprar?',
#   'label': [None],
#   'index': 646,
#   'id_post': '504821172912906_923654317696254'},
#  {'text': 'Cristiano Neves',
#   'label': [None],
#   'index': 1991,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'Seleta e triunfo foram as melhores que tomei armazenada em umburana',
#   'label': [None],
#   'index': 7280,
#   'id_post': '419227044768933_1774360212588936'},
#  {'text': 'Reservei 3! 🙈',
#   'label': [None],
#   'index': 111,
#   'id_post': '289946744351052_3951497998195890'},
#  {'text': 'Tudo de bom!',
#   'label': [None],
#   'index': 86,
#   'id_post': '678132495559046_4321557251216534'},
#  {'text': 'E a minha em eu quero experimentar',
#   'label': [None],
#   'index': 12553,
#   'id_post': '419227044768933_1165056406852656'},
#  {'text': 'Showwww!!!',
#   'label': [None],
#   'index': 1031,
#   'id_post': '289946744351052_2008710315808011'},
#  {'text': 'Parabens Wilson e Alan e grata por tudo e pelo apoio de sempre!  Vocês  são ótimos!',
#   'label': [None],
#   'index': 830,
#   'id_post': '154327584714197_430848007062152'},
#  {'text': 'Há muitas cachaças boas! Mas VALE VERDE é a melhor *****',
#   'label': [None],
#   'index': 12008,
#   'id_post': '419227044768933_1288039177887711'},
#  {'text': 'Olha aí Geziel Francisquini Franco!',
#   'label': [None],
#   'index': 9658,
#   'id_post': '419227044768933_1696658903692401'},
#  {'text': '👏👏👏',
#   'label': [None],
#   'index': 24,
#   'id_post': '154327584714197_1528115780668697'},
#  {'text': 'Linda Garrafa! Parabéns!',
#   'label': [None],
#   'index': 5303,
#   'id_post': '403465119681680_1022581231103396'},
#  {'text': 'Spiral, 1000 Montes, Amarogutta, Honey Huntr, Primeira de Minas, Genuina Jambu.',
#   'label': [None],
#   'index': 6587,
#   'id_post': '419227044768933_1795028987188725'},
#  {'text': 'Parabéns Aninha!!!!',
#   'label': [None],
#   'index': 455,
#   'id_post': '264760870213527_2453554088000850'},
#  {'text': 'Parabéns João Luís!!!!',
#   'label': [None],
#   'index': 717,
#   'id_post': '264760870213527_1423227441033525'},
#  {'text': 'Karol Pecorari la do engenho',
#   'label': [None],
#   'index': 3039,
#   'id_post': '678132495559046_1854623494576601'},
#  {'text': 'Eta pinga boa!',
#   'label': [None],
#   'index': 5449,
#   'id_post': '419227044768933_1880456268645996'},
#  {'text': 'Salinas',
#   'label': [None],
#   'index': 3823,
#   'id_post': '419227044768933_2604935762864706'},
#  {'text': 'Adorooo A melhor',
#   'label': [None],
#   'index': 2364,
#   'id_post': '678132495559046_3028919067147032'},
#  {'text': 'Parece otima',
#   'label': [None],
#   'index': 12054,
#   'id_post': '419227044768933_1277495555608740'},
#  {'text': 'Opa, vamos conhecer.',
#   'label': [None],
#   'index': 12405,
#   'id_post': '419227044768933_1193619950662968'},
#  {'text': 'Delícia',
#   'label': [None],
#   'index': 1983,
#   'id_post': '403465119681680_3364859013542261'},
#  {'text': 'Eu quero',
#   'label': [None],
#   'index': 2978,
#   'id_post': '678132495559046_1855099794528971'},
#  {'text': 'Fabrício Bernardes Bárbara Parente da Costa André Luiz Gimenez Baksa',
#   'label': [None],
#   'index': 445,
#   'id_post': '504821172912906_1517528978308782'},
#  {'text': 'Juro que eu li cereja 🙊',
#   'label': [None],
#   'index': 157,
#   'id_post': '120086268098178_478300958943372'},
#  {'text': '#licores #coqueteis #cachacas #domtapparo #ofertas #promocoes #compras #bebidas #mercadao #mercadaodesp #portaldomercadao',
#   'label': [None],
#   'index': 198,
#   'id_post': '202088406473061_4740962209252302'},
#  {'text': 'Adriano Castro Nilson Siqueira',
#   'label': [None],
#   'index': 4843,
#   'id_post': '403465119681680_1964824473545729'},
#  {'text': 'Lívia Freitas',
#   'label': [None],
#   'index': 3002,
#   'id_post': '678132495559046_1854623494576601'},
#  {'text': 'Olha vinicios ela a kenga cachaça',
#   'label': [None],
#   'index': 10367,
#   'id_post': '419227044768933_1655005651191060'},
#  {'text': 'João Victor Nohama kkkkkkkkk',
#   'label': [None],
#   'index': 241,
#   'id_post': '120086268098178_336080283165441'},
#  {'text': 'Era só mudar uma letrinha de lugar e colocava a TIÊ lá no canto direito...',
#   'label': [None],
#   'index': 1277,
#   'id_post': '419227044768933_3241532495871693'},
#  {'text': 'Preciso de amostra e preço',
#   'label': [None],
#   'index': 2949,
#   'id_post': '678132495559046_1919338311438452'},
#  {'text': 'Manda pra mim',
#   'label': [None],
#   'index': 125,
#   'id_post': '100997261363161_187485026047717'},
#  {'text': 'Claudio Eustaquio Gomes Junior\nHebert Rodrigues',
#   'label': [None],
#   'index': 4961,
#   'id_post': '403465119681680_1964824473545729'},
#  {'text': 'Thiago Molina',
#   'label': [None],
#   'index': 2020,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'Faltou Eduardo Costa .',
#   'label': [None],
#   'index': 1120,
#   'id_post': '678132495559046_3528569993848601'},
#  {'text': 'Pedro Henrique Prado',
#   'label': [None],
#   'index': 2678,
#   'id_post': '403465119681680_2945386155489551'},
#  {'text': 'Deliciosa!!',
#   'label': [None],
#   'index': 13233,
#   'id_post': '419227044768933_983397855018513'},
#  {'text': 'Voce acha mesmo que bebida alcoolica necessita de mais promocao?',
#   'label': [None],
#   'index': 14571,
#   'id_post': '419227044768933_544890645535905'},
#  {'text': 'Rensga que tanto de delícia...Que pena que é tão cara😢',
#   'label': [None],
#   'index': 2921,
#   'id_post': '678132495559046_1926891844016432'},
#  {'text': 'Delícia.',
#   'label': [None],
#   'index': 121,
#   'id_post': '255267772952_10157399720452953'},
#  {'text': 'Elenice Inhaia Alessandro Carvalho Claito Inhaia kkkkkk pra vc nice',
#   'label': [None],
#   'index': 320,
#   'id_post': '504821172912906_1678531985541813'},
#  {'text': 'Vacina SIM CACHAÇARIA SIM.',
#   'label': [None],
#   'index': 303,
#   'id_post': '403465119681680_4588764434485040'},
#  {'text': 'José Antonio ',
#   'label': [None],
#   'index': 1909,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'Um luxo',
#   'label': [None],
#   'index': 591,
#   'id_post': '445596452143103_1667953083240761'},
#  {'text': 'Daniela Oliveira\nLaudceia Santos',
#   'label': [None],
#   'index': 4742,
#   'id_post': '403465119681680_1964824473545729'},
#  {'text': 'Tô nessa. Boa tarde.',
#   'label': [None],
#   'index': 2533,
#   'id_post': '289946744351052_647729995239390'},
#  {'text': '✌✌✌✌',
#   'label': [None],
#   'index': 117,
#   'id_post': '255267772952_10157445423597953'},
#  {'text': 'Juliana Moraes olha pra nós gatinhas 😁😁😁',
#   'label': [None],
#   'index': 3788,
#   'id_post': '403465119681680_2179913552036819'},
#  {'text': 'Hulk',
#   'label': [None],
#   'index': 9952,
#   'id_post': '419227044768933_1686845488007076'},
#  {'text': 'Ele tinha feito com Ypioca',
#   'label': [None],
#   'index': 1082,
#   'id_post': '154327584714197_235443103269311'},
#  {'text': 'A  onde  encontra aki em  Manaus esse produto???',
#   'label': [None],
#   'index': 919,
#   'id_post': '289946744351052_2186390208040020'},
#  {'text': 'Lindo!',
#   'label': [None],
#   'index': 227,
#   'id_post': '154327584714197_1007585422721738'},
#  {'text': 'Qual o valor :?',
#   'label': [None],
#   'index': 6577,
#   'id_post': '678132495559046_926298180742475'},
#  {'text': 'Vocês não  conhecem a Rainha  e Serra  Limpa  da PARAÍBA  \nÉ  só  uma  sugestão.',
#   'label': [None],
#   'index': 7867,
#   'id_post': '419227044768933_1763528423672115'},
#  {'text': 'Frete Gratis!!!!??? Vale pra Dinamarca???',
#   'label': [None],
#   'index': 240,
#   'id_post': '255267772952_10155944096477953'},
#  {'text': 'Rúbia Mendes',
#   'label': [None],
#   'index': 5799,
#   'id_post': '678132495559046_1392962117409410'},
#  {'text': 'Lili Sena Pinheiro ',
#   'label': [None],
#   'index': 542,
#   'id_post': '678132495559046_4087040058001589'},
#  {'text': 'É o Reinilson?',
#   'label': [None],
#   'index': 12340,
#   'id_post': '419227044768933_1200758383282458'},
#  {'text': 'sempre  uma  dose   cai  muito  bem..',
#   'label': [None],
#   'index': 13638,
#   'id_post': '419227044768933_840197599338540'},
#  {'text': 'Deiverson Armando de Oliveira, é hoje... Kkk',
#   'label': [None],
#   'index': 4239,
#   'id_post': '419227044768933_2462854987072785'},
#  {'text': 'Mostra pro Sr Ronaldo depois D. Eliane!! 😘',
#   'label': [None],
#   'index': 12181,
#   'id_post': '419227044768933_1242351699123126'},
#  {'text': 'Eu e meu amigo Luiz Roberto Zamora Zamora, já tivemos o prazer deste brinde “sofisticado”...',
#   'label': [None],
#   'index': 10168,
#   'id_post': '419227044768933_1668637853161173'},
#  {'text': 'Me dá de presente  vocês  vem em Iturama  ne amadinho beijo',
#   'label': [None],
#   'index': 4797,
#   'id_post': '678132495559046_1395634240475531'},
#  {'text': 'Chique',
#   'label': [None],
#   'index': 1236,
#   'id_post': '289946744351052_1923648567647520'},
#  {'text': 'Hoje vou brindar com uma BUCCO BRANCA que chegou essa semana pra mim,',
#   'label': [None],
#   'index': 1058,
#   'id_post': '419227044768933_3437750576249883'},
#  {'text': 'Chã- Grande muito bem representada. Cachaça orgânica, de Chã - Grande para o mundo ! Sucesso sempre  👏👌',
#   'label': [None],
#   'index': 1470,
#   'id_post': '289946744351052_1675931692419210'},
#  {'text': 'Bruna',
#   'label': [None],
#   'index': 5022,
#   'id_post': '678132495559046_1392962117409410'},
#  {'text': 'E muito bom assisti los',
#   'label': [None],
#   'index': 4490,
#   'id_post': '678132495559046_1411592662213022'},
#  {'text': 'Apesar de poderem se referir à mesm bebida, as 3 palavras não são sinônimas. Aguardente é o nome de qualquer bebida obtida a partir da fermentação de vegetais doces. Já cachaça é o nome da aguardente de cana-de-açúcar. ... Já pinga é o nome vulgar da cachaça.',
#   'label': [None],
#   'index': 41,
#   'id_post': '366862246737093_2521839757905987'},
#  {'text': 'Olha Rafaela Cristina Ferraz',
#   'label': [None],
#   'index': 5400,
#   'id_post': '678132495559046_1392962117409410'},
#  {'text': 'Sou fã e quero uma!\nComo proceder?',
#   'label': [None],
#   'index': 396,
#   'id_post': '289946744351052_3232153096797054'},
#  {'text': "Fernanda S'Lima ta inaugurando hoje aqui no parque do lago 😍😍😍",
#   'label': [None],
#   'index': 859,
#   'id_post': '154327584714197_412258862254400'},
#  {'text': 'O grande',
#   'label': [None],
#   'index': 8144,
#   'id_post': '419227044768933_1752002038158087'},
#  {'text': 'Quero conhecer este caçula da familia sanhaçu que estar para nascer que venha com muito sabor aos nossos paladares bjs',
#   'label': [None],
#   'index': 1752,
#   'id_post': '289946744351052_1331546983524351'},
#  {'text': 'Eu quero um gole pra experimentar',
#   'label': [None],
#   'index': 5464,
#   'id_post': '678132495559046_1392962117409410'},
#  {'text': 'Essa cachaça eu não tenho 😭😫.',
#   'label': [None],
#   'index': 4050,
#   'id_post': '403465119681680_1974444589250384'},
#  {'text': 'Primeiramente Lula na cadeia',
#   'label': [None],
#   'index': 3190,
#   'id_post': '678132495559046_1840426409329643'},
#  {'text': 'Buenicima',
#   'label': [None],
#   'index': 690,
#   'id_post': '504821172912906_648386075223081'},
#  {'text': 'Marcio Martins😂😂😂não é tão caro não ',
#   'label': [None],
#   'index': 33,
#   'id_post': '372443083246910_840783446412869'},
#  {'text': 'Reserva 51 singular',
#   'label': [None],
#   'index': 7274,
#   'id_post': '419227044768933_1774360212588936'},
#  {'text': 'Parabéns que Deus abençoe sempre',
#   'label': [None],
#   'index': 645,
#   'id_post': '154327584714197_647556865391264'},
#  {'text': 'Site ta show! Parabéns! Sucesso!',
#   'label': [None],
#   'index': 865,
#   'id_post': '929114380449752_1175172142510640'},
#  {'text': '👏👏👏👏👏',
#   'label': [None],
#   'index': 161,
#   'id_post': '255267772952_10157271297117953'},
#  {'text': 'Um espetáculo',
#   'label': [None],
#   'index': 11145,
#   'id_post': '419227044768933_1549993978358895'},
#  {'text': 'Eu quero',
#   'label': [None],
#   'index': 6104,
#   'id_post': '678132495559046_1389014874470801'},
#  {'text': 'Jake Souza o que me diz?',
#   'label': [None],
#   'index': 1900,
#   'id_post': '403465119681680_3364859013542261'},
#  {'text': '0',
#   'label': [None],
#   'index': 4219,
#   'id_post': '419227044768933_2516677485023868'},
#  {'text': 'Zé Coltrane Silva no playback',
#   'label': [None],
#   'index': 5920,
#   'id_post': '419227044768933_1823140961044194'},
#  {'text': 'É Lorena Amorim, como você mesmo disse qualquer vodka cairia muito bem, mais caso você ganhasse o nosso vale-compra e trocasse pela Vodka Absolut 100 (R$ 89,90) você ainda teria R$10.10 podendo pegar, por exemplo, Red Bull 250ml (R$6,99)!',
#   'label': [None],
#   'index': 651,
#   'id_post': '120086268098178_186924451394439'},
#  {'text': 'O Lula ladrão é freguês desse recinto de cachaceiro.',
#   'label': [None],
#   'index': 949,
#   'id_post': '419227044768933_3568582416500031'},
#  {'text': 'Edinalva Sena Aldo Medeiros',
#   'label': [None],
#   'index': 4927,
#   'id_post': '403465119681680_1964824473545729'},
#  {'text': 'Prefiro ser um bêbado conhecido, do que em alcoolatra anônimo.',
#   'label': [None],
#   'index': 292,
#   'id_post': '929114380449752_1694248013936381'},
#  {'text': 'Marialva. Espetacular!!!',
#   'label': [None],
#   'index': 6748,
#   'id_post': '419227044768933_1785001964858094'},
#  {'text': 'É um whisky pra quem não entende nada de whisky, me bloquearam no Instagram por falar a verdade sobre whiskys, empresa piada, sei que logo vai apagar meu comentário aqui também. Pra todos que verem esse meu comentário, saiba que não recomendo a casa das bebidas, a Amazon tem muito mais variedade e preço!! Fui',
#   'label': [None],
#   'index': 0,
#   'id_post': '120086268098178_4083651658408266'},
#  {'text': 'Estou gostando muito da Weber House.',
#   'label': [None],
#   'index': 9686,
#   'id_post': '419227044768933_1696433050381653'},
#  {'text': 'Sabe onde posso encontrar de amendoim?',
#   'label': [None],
#   'index': 12559,
#   'id_post': '419227044768933_1162550137103283'},
#  {'text': 'Polyanna Santos Ana F Marques Samyn Anair Oliveira Carla Martins Carla Costa digam que indiquei',
#   'label': [None],
#   'index': 424,
#   'id_post': '120086268098178_173431086097029'},
#  {'text': 'Amei show',
#   'label': [None],
#   'index': 3315,
#   'id_post': '403465119681680_2550378604990310'},
#  {'text': 'Adriel Mauricio',
#   'label': [None],
#   'index': 3311,
#   'id_post': '678132495559046_1794953240543627'},
#  {'text': 'Carmem estou aqui no calorzão mesmo assim não dispenso a caipirinha com uma boa cachaça....',
#   'label': [None],
#   'index': 14727,
#   'id_post': '419227044768933_445131808845123'},
#  {'text': 'Wilson  muito bom , estou muito Feliz por ver um excelente projeto',
#   'label': [None],
#   'index': 1209,
#   'id_post': '154327584714197_161069317373357'},
#  {'text': 'Eu só sei que amei...que amei..que amei.. Será talvez, que  minha ilusão foi dar coração......\n😍😍',
#   'label': [None],
#   'index': 1317,
#   'id_post': '289946744351052_1884259584919752'},
#  {'text': 'Dupla. Boa di mais.? ???',
#   'label': [None],
#   'index': 6021,
#   'id_post': '678132495559046_1389014874470801'},
#  {'text': 'Vale a pena! Recomendo!',
#   'label': [None],
#   'index': 2380,
#   'id_post': '403465119681680_3153444188017079'},
#  {'text': 'Essa eu conheço e recomendo!!!!!',
#   'label': [None],
#   'index': 7578,
#   'id_post': '419227044768933_1771089189582705'},
#  {'text': 'Uso muito a cachaça pra flambar!!',
#   'label': [None],
#   'index': 1877,
#   'id_post': '403465119681680_3364859013542261'},
#  {'text': 'Valeria Cassemiro Dantas',
#   'label': [None],
#   'index': 2054,
#   'id_post': '403465119681680_3364859013542261'},
#  {'text': 'Marco Aurelio é esse ae ??? Kkkkkkkkkl (thiago)',
#   'label': [None],
#   'index': 3663,
#   'id_post': '678132495559046_1459415090764112'},
#  {'text': 'Parabéns meu amigo.',
#   'label': [None],
#   'index': 817,
#   'id_post': '264760870213527_1217573588265579'},
#  {'text': 'Eu amo barril nem por isso eu bebo, as pessoas tem o livre arbítrio',
#   'label': [None],
#   'index': 718,
#   'id_post': '929114380449752_1627482690612914'},
#  {'text': 'A do mundial de 51  do palmeirais kkkk',
#   'label': [None],
#   'index': 9561,
#   'id_post': '419227044768933_1697489583609333'},
#  {'text': 'Parabéns Sr. Admilson muitas felicidades e sucesso',
#   'label': [None],
#   'index': 2629,
#   'id_post': '678132495559046_1936783049693978'},
#  {'text': '7',
#   'label': [None],
#   'index': 2986,
#   'id_post': '403465119681680_2785041618190673'},
#  {'text': 'Fabricantes de boa cachcaça: Acessem nosso blog (artekraftembalagens.blogspot,com)para conhecerem nossas embalagens personalizadas',
#   'label': [None],
#   'index': 14418,
#   'id_post': '419227044768933_574585062566463'},
#  {'text': 'Ame é a quatro letra kkkkk, enquanto mais velha é gostosa pitu kkkkk',
#   'label': [None],
#   'index': 7502,
#   'id_post': '419227044768933_1773357592689198'},
#  {'text': 'Parabéns Oto',
#   'label': [None],
#   'index': 232,
#   'id_post': '289946744351052_3723305324348493'},
#  {'text': 'Parabéns família Barreto',
#   'label': [None],
#   'index': 1414,
#   'id_post': '289946744351052_1808337559178622'},
#  {'text': 'Cachaça,qd.a vejo cumprimento dizendo adeus minha bela sinto cheiro no nariz e o gosto no pé da guela...',
#   'label': [None],
#   'index': 2523,
#   'id_post': '403465119681680_3102075486487283'},
#  {'text': 'Maisa Lechado...eu quero, compra pra gente...bjs',
#   'label': [None],
#   'index': 176,
#   'id_post': '185525291482202_587100944657966'},
#  {'text': 'Minhas viagens a Ribeirão tem q ter parada aí 🥰 adoro',
#   'label': [None],
#   'index': 14,
#   'id_post': '678132495559046_4482630705109187'},
#  {'text': "We're not gonna take it... Twisted Sister.",
#   'label': [None],
#   'index': 5974,
#   'id_post': '419227044768933_1820821327942824'},
#  {'text': 'Descorado da escludividade da embalagem por provo quenho um litro com uma camada cachaça da vovó embalada em Alagoa nova  PB.',
#   'label': [None],
#   'index': 5222,
#   'id_post': '419227044768933_1930081783683444'},
#  {'text': 'Genteeeee onde eu compro isso!??? Ariádne Delgado Laís Araújo Marcela Delai Caroline Freschi',
#   'label': [None],
#   'index': 5935,
#   'id_post': '678132495559046_1392962117409410'},
#  {'text': 'que delicia!!!! kkkkk',
#   'label': [None],
#   'index': 12251,
#   'id_post': '419227044768933_1220300547994908'},
#  {'text': 'Projeto em ação tio Wellington Felix???',
#   'label': [None],
#   'index': 1669,
#   'id_post': '289946744351052_1414933391852376'},
#  {'text': 'Parabens!!! Sucesso!!',
#   'label': [None],
#   'index': 3921,
#   'id_post': '403465119681680_2050365514991624'},
#  {'text': 'Cachaça top d mais não queima.',
#   'label': [None],
#   'index': 6217,
#   'id_post': '678132495559046_1264971013541855'},
#  {'text': 'Difícil é encontrar onde comprar !!!',
#   'label': [None],
#   'index': 10655,
#   'id_post': '419227044768933_1617107101647582'},
#  {'text': 'Fabrício Vasconcellos',
#   'label': [None],
#   'index': 1501,
#   'id_post': '678132495559046_3528569993848601'},
#  {'text': 'ja faço isso a muito tempo por aqui.....tambem na versão doce',
#   'label': [None],
#   'index': 1565,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'Boa !',
#   'label': [None],
#   'index': 118,
#   'id_post': '372443083246910_398284153996136'},
#  {'text': 'Carvalheira, Piragibana,',
#   'label': [None],
#   'index': 1284,
#   'id_post': '419227044768933_3241532495871693'},
#  {'text': 'Igno Magno',
#   'label': [None],
#   'index': 2602,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'Gosto de uma boa cachaça.',
#   'label': [None],
#   'index': 1394,
#   'id_post': '403465119681680_3580789348615892'},
#  {'text': 'Olá Esther Antunes com o nosso vale-compra de RS100.00 da promoção A Casa da Bebida faz o seu Esquenta, você consegue trocar por 4 Vodka Smirnoff Natural (R$24,90). Ótima escolha!',
#   'label': [None],
#   'index': 642,
#   'id_post': '120086268098178_186924451394439'},
#  {'text': 'Isso é mais velho que a procissão de caga',
#   'label': [None],
#   'index': 1701,
#   'id_post': '419227044768933_3221539371204339'},
#  {'text': 'Stéphanie Almeida Elizabeth Terto De Carvalho Julia Harumi Faria',
#   'label': [None],
#   'index': 434,
#   'id_post': '504821172912906_1517528978308782'},
#  {'text': 'Ótimo presente pra mim mesmo',
#   'label': [None],
#   'index': 6438,
#   'id_post': '678132495559046_995929697112656'},
#  {'text': 'Diogenes Alves DE Oliveira, olha essa meu querido !!',
#   'label': [None],
#   'index': 12879,
#   'id_post': '419227044768933_1072714149420216'},
#  {'text': 'Sanhaçu...Sucesso Nacional!',
#   'label': [None],
#   'index': 1957,
#   'id_post': '289946744351052_1121704284508623'}]
